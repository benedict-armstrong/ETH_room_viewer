# %%
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime, timedelta

# %%
def set_date(date: datetime, s):
    """
    Return date in format 'dd.mm.yyyy' or 'time' if s is not a string
    s is a string in format '... dd.mm'
    """

    if isinstance(s, str):
        if (date.month == 12 and s[-2:] == '01'):
            return "{}.{}".format(s[-5:], date.year + 1)

        return "{}.{}".format(s[-5:], date.year)
    else:
        return 'time'

# %%
date = datetime.now()
monday = date - timedelta(days = date.weekday())
html = ''
room_id = 1

# %%
with open('test.html') as fp:
    html = fp.read()

soup = BeautifulSoup(html, 'html.parser')
table = soup.findAll('table')[1]

# %%
df = pd.read_html(table.prettify())[0]

# %%
df.iloc[:, 0] = df.iloc[:, 0].str.split('-').str[0]
df[df.columns[0]] = pd.to_datetime(df.iloc[:, 0], format='%H')

# %%
# add 0, 15, 30, 45 minutes to the hour (repeat every 4 rows)
df.iloc[2::4, 0] = df.iloc[2::4, 0] + pd.Timedelta(minutes=15)
df.iloc[3::4, 0] = df.iloc[3::4, 0] + pd.Timedelta(minutes=30)
df.iloc[4::4, 0] = df.iloc[4::4, 0] + pd.Timedelta(minutes=45)

# %%
# drop column 1
df = df.drop(df.columns[1], axis=1)

# %%
# set columns to dates
df.columns = df.iloc[0]
df = df[1:]
df.rename(columns=lambda col: set_date(date=date, s=col), inplace=True)

# %%
# set index to time
df.index = df["time"]
df = df.drop(df.columns[0], axis=1)

df.columns = pd.to_datetime(df.columns, format='%d.%m.%Y')

# %%
for day in df.columns:
    # drop all lines with empty strings
    lectures_on_day = df[day].dropna()
    lectures_on_day.index = lectures_on_day.index.map(lambda t: datetime.combine(day, t.time()))
    # print(lectures_on_day)

    if len(lectures_on_day) > 0:
        # iterate over lectures and combine them if they have the same name keeping track of duration and start time
        prev_name = ''
        start_time = datetime.now()
        duration = timedelta()

        for time, name in lectures_on_day.items():
            # print(time, name)
            if name == prev_name:
                duration += timedelta(minutes=15)
            else:
                if prev_name != '':
                    print(prev_name, duration, start_time)
                prev_name = name
                start_time = time
                duration = timedelta(minutes=15)

        print(prev_name, duration, start_time)
# Out:
# Land-Climate Dynamics  Seneviratne S., Pa... 1:30:00 2023-01-30 12:30:00

# %%
df
# Out:
# 0                                                      2023-01-30 2023-01-31  \
# time
# 1900-01-01 07:00:00                                           NaN        NaN
# 1900-01-01 07:15:00                                           NaN        NaN
# 1900-01-01 07:30:00                                           NaN        NaN
# 1900-01-01 07:45:00                                           NaN        NaN
# 1900-01-01 08:00:00                                           NaN        NaN
# 1900-01-01 08:15:00                                           NaN        NaN
# 1900-01-01 08:30:00                                           NaN        NaN
# 1900-01-01 08:45:00                                           NaN        NaN
# 1900-01-01 09:00:00                                           NaN        NaN
# 1900-01-01 09:15:00                                           NaN        NaN
# 1900-01-01 09:30:00                                           NaN        NaN
# 1900-01-01 09:45:00                                           NaN        NaN
# 1900-01-01 10:00:00                                           NaN        NaN
# 1900-01-01 10:15:00                                           NaN        NaN
# 1900-01-01 10:30:00                                           NaN        NaN
# 1900-01-01 10:45:00                                           NaN        NaN
# 1900-01-01 11:00:00                                           NaN        NaN
# 1900-01-01 11:15:00                                           NaN        NaN
# 1900-01-01 11:30:00                                           NaN        NaN
# 1900-01-01 11:45:00                                           NaN        NaN
# 1900-01-01 12:00:00                                           NaN        NaN
# 1900-01-01 12:15:00                                           NaN        NaN
# 1900-01-01 12:30:00  Land-Climate Dynamics  Seneviratne S., Pa...        NaN
# 1900-01-01 12:45:00  Land-Climate Dynamics  Seneviratne S., Pa...        NaN
# 1900-01-01 13:00:00  Land-Climate Dynamics  Seneviratne S., Pa...        NaN
# 1900-01-01 13:15:00  Land-Climate Dynamics  Seneviratne S., Pa...        NaN
# 1900-01-01 13:30:00  Land-Climate Dynamics  Seneviratne S., Pa...        NaN
# 1900-01-01 13:45:00  Land-Climate Dynamics  Seneviratne S., Pa...        NaN
# 1900-01-01 14:00:00                                           NaN        NaN
# 1900-01-01 14:15:00                                           NaN        NaN
# 1900-01-01 14:30:00                                           NaN        NaN
# 1900-01-01 14:45:00                                           NaN        NaN
# 1900-01-01 15:00:00                                           NaN        NaN
# 1900-01-01 15:15:00                                           NaN        NaN
# 1900-01-01 15:30:00                                           NaN        NaN
# 1900-01-01 15:45:00                                           NaN        NaN
# 1900-01-01 16:00:00                                           NaN        NaN
# 1900-01-01 16:15:00                                           NaN        NaN
# 1900-01-01 16:30:00                                           NaN        NaN
# 1900-01-01 16:45:00                                           NaN        NaN
# 1900-01-01 17:00:00                                           NaN        NaN
# 1900-01-01 17:15:00                                           NaN        NaN
# 1900-01-01 17:30:00                                           NaN        NaN
# 1900-01-01 17:45:00                                           NaN        NaN
# 1900-01-01 18:00:00                                           NaN        NaN
# 1900-01-01 18:15:00                                           NaN        NaN
# 1900-01-01 18:30:00                                           NaN        NaN
# 1900-01-01 18:45:00                                           NaN        NaN
# 1900-01-01 19:00:00                                           NaN        NaN
# 1900-01-01 19:15:00                                           NaN        NaN
# 1900-01-01 19:30:00                                           NaN        NaN
# 1900-01-01 19:45:00                                           NaN        NaN
# 1900-01-01 20:00:00                                           NaN        NaN
# 1900-01-01 20:15:00                                           NaN        NaN
# 1900-01-01 20:30:00                                           NaN        NaN
# 1900-01-01 20:45:00                                           NaN        NaN
# 1900-01-01 21:00:00                                           NaN        NaN
# 1900-01-01 21:15:00                                           NaN        NaN
# 1900-01-01 21:30:00                                           NaN        NaN
# 1900-01-01 21:45:00                                           NaN        NaN
#
# 0                   2023-02-01 2023-02-02 2023-02-03 2023-02-04
# time
# 1900-01-01 07:00:00        NaN        NaN        NaN        NaN
# 1900-01-01 07:15:00        NaN        NaN        NaN        NaN
# 1900-01-01 07:30:00        NaN        NaN        NaN        NaN
# 1900-01-01 07:45:00        NaN        NaN        NaN        NaN
# 1900-01-01 08:00:00        NaN        NaN        NaN        NaN
# 1900-01-01 08:15:00        NaN        NaN        NaN        NaN
# 1900-01-01 08:30:00        NaN        NaN        NaN        NaN
# 1900-01-01 08:45:00        NaN        NaN        NaN        NaN
# 1900-01-01 09:00:00        NaN        NaN        NaN        NaN
# 1900-01-01 09:15:00        NaN        NaN        NaN        NaN
# 1900-01-01 09:30:00        NaN        NaN        NaN        NaN
# 1900-01-01 09:45:00        NaN        NaN        NaN        NaN
# 1900-01-01 10:00:00        NaN        NaN        NaN        NaN
# 1900-01-01 10:15:00        NaN        NaN        NaN        NaN
# 1900-01-01 10:30:00        NaN        NaN        NaN        NaN
# 1900-01-01 10:45:00        NaN        NaN        NaN        NaN
# 1900-01-01 11:00:00        NaN        NaN        NaN        NaN
# 1900-01-01 11:15:00        NaN        NaN        NaN        NaN
# 1900-01-01 11:30:00        NaN        NaN        NaN        NaN
# 1900-01-01 11:45:00        NaN        NaN        NaN        NaN
# 1900-01-01 12:00:00        NaN        NaN        NaN        NaN
# 1900-01-01 12:15:00        NaN        NaN        NaN        NaN
# 1900-01-01 12:30:00        NaN        NaN        NaN        NaN
# 1900-01-01 12:45:00        NaN        NaN        NaN        NaN
# 1900-01-01 13:00:00        NaN        NaN        NaN        NaN
# 1900-01-01 13:15:00        NaN        NaN        NaN        NaN
# 1900-01-01 13:30:00        NaN        NaN        NaN        NaN
# 1900-01-01 13:45:00        NaN        NaN        NaN        NaN
# 1900-01-01 14:00:00        NaN        NaN        NaN        NaN
# 1900-01-01 14:15:00        NaN        NaN        NaN        NaN
# 1900-01-01 14:30:00        NaN        NaN        NaN        NaN
# 1900-01-01 14:45:00        NaN        NaN        NaN        NaN
# 1900-01-01 15:00:00        NaN        NaN        NaN        NaN
# 1900-01-01 15:15:00        NaN        NaN        NaN        NaN
# 1900-01-01 15:30:00        NaN        NaN        NaN        NaN
# 1900-01-01 15:45:00        NaN        NaN        NaN        NaN
# 1900-01-01 16:00:00        NaN        NaN        NaN        NaN
# 1900-01-01 16:15:00        NaN        NaN        NaN        NaN
# 1900-01-01 16:30:00        NaN        NaN        NaN        NaN
# 1900-01-01 16:45:00        NaN        NaN        NaN        NaN
# 1900-01-01 17:00:00        NaN        NaN        NaN        NaN
# 1900-01-01 17:15:00        NaN        NaN        NaN        NaN
# 1900-01-01 17:30:00        NaN        NaN        NaN        NaN
# 1900-01-01 17:45:00        NaN        NaN        NaN        NaN
# 1900-01-01 18:00:00        NaN        NaN        NaN        NaN
# 1900-01-01 18:15:00        NaN        NaN        NaN        NaN
# 1900-01-01 18:30:00        NaN        NaN        NaN        NaN
# 1900-01-01 18:45:00        NaN        NaN        NaN        NaN
# 1900-01-01 19:00:00        NaN        NaN        NaN        NaN
# 1900-01-01 19:15:00        NaN        NaN        NaN        NaN
# 1900-01-01 19:30:00        NaN        NaN        NaN        NaN
# 1900-01-01 19:45:00        NaN        NaN        NaN        NaN
# 1900-01-01 20:00:00        NaN        NaN        NaN        NaN
# 1900-01-01 20:15:00        NaN        NaN        NaN        NaN
# 1900-01-01 20:30:00        NaN        NaN        NaN        NaN
# 1900-01-01 20:45:00        NaN        NaN        NaN        NaN
# 1900-01-01 21:00:00        NaN        NaN        NaN        NaN
# 1900-01-01 21:15:00        NaN        NaN        NaN        NaN
# 1900-01-01 21:30:00        NaN        NaN        NaN        NaN
# 1900-01-01 21:45:00        NaN        NaN        NaN        NaN
